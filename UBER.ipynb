# %% [markdown]
# <a href="https://colab.research.google.com/github/wjyrskyy14-ctrl/python-basic-For-Data-Science/blob/main/UBER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ncr_ride_bookings.csv')

# %% [markdown]
# # DATA UNDERSTANDING

# %%
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# 0  ...                                NaN                       NaN
# 1  ...                                NaN                       NaN
# 2  ...                                NaN                       NaN
# 3  ...                                NaN                       NaN
# 4  ...                                NaN                       NaN
#
#    Driver Cancellation Reason Incomplete Rides  Incomplete Rides Reason  \
# 0                         NaN              NaN                      NaN
# 1                         NaN              1.0        Vehicle Breakdown
# 2                         NaN              NaN                      NaN
# 3                         NaN              NaN                      NaN
# 4                         NaN              NaN                      NaN
#
#   Booking Value  Ride Distance  Driver Ratings  Customer Rating  \
# 0           NaN            NaN             NaN              NaN
# 1         237.0           5.73             NaN              NaN
# 2         627.0          13.58             4.9              4.9
# 3         416.0          34.02             4.6              5.0
# 4         737.0          48.21             4.1              4.3
#
#    Payment Method
# 0             NaN
# 1             UPI
# 2      Debit Card
# 3             UPI
# 4             UPI
#
# [5 rows x 21 columns]

# %%
df = df.set_index('Date')

# %%
df.head()
# Out:
#                 Time    Booking ID   Booking Status   Customer ID  \
# Date
# 2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#              Vehicle Type      Pickup Location      Drop Location  Avg VTAT  \
# Date
# 2024-03-23          eBike          Palam Vihar            Jhilmil       NaN
# 2024-11-29       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9
# 2024-08-23           Auto              Khandsa      Malviya Nagar      13.4
# 2024-10-21  Premier Sedan  Central Secretariat           Inderlok      13.1
# 2024-09-16           Bike     Ghitorni Village        Khan Market       5.3
#
#             Avg CTAT  Cancelled Rides by Customer  \
# Date
# 2024-03-23       NaN                          NaN
# 2024-11-29      14.0                          NaN
# 2024-08-23      25.8                          NaN
# 2024-10-21      28.5                          NaN
# 2024-09-16      19.6                          NaN
#
#            Reason for cancelling by Customer  Cancelled Rides by Driver  \
# Date
# 2024-03-23                               NaN                        NaN
# 2024-11-29                               NaN                        NaN
# 2024-08-23                               NaN                        NaN
# 2024-10-21                               NaN                        NaN
# 2024-09-16                               NaN                        NaN
#
#            Driver Cancellation Reason  Incomplete Rides  \
# Date
# 2024-03-23                        NaN               NaN
# 2024-11-29                        NaN               1.0
# 2024-08-23                        NaN               NaN
# 2024-10-21                        NaN               NaN
# 2024-09-16                        NaN               NaN
#
#            Incomplete Rides Reason  Booking Value  Ride Distance  \
# Date
# 2024-03-23                     NaN            NaN            NaN
# 2024-11-29       Vehicle Breakdown          237.0           5.73
# 2024-08-23                     NaN          627.0          13.58
# 2024-10-21                     NaN          416.0          34.02
# 2024-09-16                     NaN          737.0          48.21
#
#             Driver Ratings  Customer Rating Payment Method
# Date
# 2024-03-23             NaN              NaN            NaN
# 2024-11-29             NaN              NaN            UPI
# 2024-08-23             4.9              4.9     Debit Card
# 2024-10-21             4.6              5.0            UPI
# 2024-09-16             4.1              4.3            UPI

# %%
df[df['Driver Ratings'].notna()]
# Out:
#                 Time    Booking ID Booking Status   Customer ID  \
# Date
# 2024-08-23  08:56:10  "CNR8494506"      Completed  "CID9202816"
# 2024-10-21  17:17:25  "CNR8906825"      Completed  "CID2610914"
# 2024-09-16  22:08:00  "CNR1950162"      Completed  "CID9933542"
# 2024-02-06  09:44:56  "CNR4096693"      Completed  "CID4670564"
# 2024-06-17  15:45:58  "CNR2002539"      Completed  "CID6800553"
# ...              ...           ...            ...           ...
# 2024-11-11  19:34:01  "CNR6500631"      Completed  "CID4337371"
# 2024-11-24  15:55:09  "CNR2468611"      Completed  "CID2325623"
# 2024-09-18  10:55:15  "CNR6358306"      Completed  "CID9925486"
# 2024-10-05  07:53:34  "CNR3030099"      Completed  "CID9415487"
# 2024-03-10  15:38:03  "CNR3447390"      Completed  "CID4108667"
#
#              Vehicle Type         Pickup Location      Drop Location  \
# Date
# 2024-08-23           Auto                 Khandsa      Malviya Nagar
# 2024-10-21  Premier Sedan     Central Secretariat           Inderlok
# 2024-09-16           Bike        Ghitorni Village        Khan Market
# 2024-02-06           Auto                   AIIMS        Narsinghpur
# 2024-06-17        Go Mini                Vaishali       Punjabi Bagh
# ...                   ...                     ...                ...
# 2024-11-11        Go Mini                 MG Road           Ghitorni
# 2024-11-24        Go Mini        Golf Course Road         Akshardham
# 2024-09-18       Go Sedan  Satguru Ram Singh Marg           Jor Bagh
# 2024-10-05           Auto               Ghaziabad         Saidulajab
# 2024-03-10  Premier Sedan         Ashok Park Main  Gurgaon Sector 29
#
#             Avg VTAT  Avg CTAT  Cancelled Rides by Customer  \
# Date
# 2024-08-23      13.4      25.8                          NaN
# 2024-10-21      13.1      28.5                          NaN
# 2024-09-16       5.3      19.6                          NaN
# 2024-02-06       5.1      18.1                          NaN
# 2024-06-17       7.1      20.4                          NaN
# ...              ...       ...                          ...
# 2024-11-11      10.2      44.4                          NaN
# 2024-11-24       5.1      30.8                          NaN
# 2024-09-18       2.7      23.4                          NaN
# 2024-10-05       6.9      39.6                          NaN
# 2024-03-10       3.5      33.7                          NaN
#
#            Reason for cancelling by Customer  Cancelled Rides by Driver  \
# Date
# 2024-08-23                               NaN                        NaN
# 2024-10-21                               NaN                        NaN
# 2024-09-16                               NaN                        NaN
# 2024-02-06                               NaN                        NaN
# 2024-06-17                               NaN                        NaN
# ...                                      ...                        ...
# 2024-11-11                               NaN                        NaN
# 2024-11-24                               NaN                        NaN
# 2024-09-18                               NaN                        NaN
# 2024-10-05                               NaN                        NaN
# 2024-03-10                               NaN                        NaN
#
#            Driver Cancellation Reason  Incomplete Rides  \
# Date
# 2024-08-23                        NaN               NaN
# 2024-10-21                        NaN               NaN
# 2024-09-16                        NaN               NaN
# 2024-02-06                        NaN               NaN
# 2024-06-17                        NaN               NaN
# ...                               ...               ...
# 2024-11-11                        NaN               NaN
# 2024-11-24                        NaN               NaN
# 2024-09-18                        NaN               NaN
# 2024-10-05                        NaN               NaN
# 2024-03-10                        NaN               NaN
#
#            Incomplete Rides Reason  Booking Value  Ride Distance  \
# Date
# 2024-08-23                     NaN          627.0          13.58
# 2024-10-21                     NaN          416.0          34.02
# 2024-09-16                     NaN          737.0          48.21
# 2024-02-06                     NaN          316.0           4.85
# 2024-06-17                     NaN          640.0          41.24
# ...                            ...            ...            ...
# 2024-11-11                     NaN          475.0          40.08
# 2024-11-24                     NaN         1093.0          21.31
# 2024-09-18                     NaN          852.0          15.93
# 2024-10-05                     NaN          333.0          45.54
# 2024-03-10                     NaN          806.0          21.19
#
#             Driver Ratings  Customer Rating Payment Method
# Date
# 2024-08-23             4.9              4.9     Debit Card
# 2024-10-21             4.6              5.0            UPI
# 2024-09-16             4.1              4.3            UPI
# 2024-02-06             4.1              4.6            UPI
# 2024-06-17             4.0              4.1            UPI
# ...                    ...              ...            ...
# 2024-11-11             3.7              4.1    Uber Wallet
# 2024-11-24             4.8              5.0            UPI
# 2024-09-18             3.9              4.4           Cash
# 2024-10-05             4.1              3.7            UPI
# 2024-03-10             4.6              4.9    Credit Card
#
# [93000 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150000 entries, 2024-03-23 to 2024-03-10
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Time                               150000 non-null  object
#  1   Booking ID                         150000 non-null  object
#  2   Booking Status                     150000 non-null  object
#  3   Customer ID                        150000 non-null  object
#  4   Vehicle Type                       150000 non-null  object
#  5   Pickup Location                    150000 non-null  object
#  6   Drop Location                      150000 non-null  object
#  7   Avg VTAT                           139500 non-null  float64
#  8   Avg CTAT                           102000 non-null  float64
#  9   Cancelled Rides by Customer        10500 non-null   float64
#  10  Reason for cancelling by Customer  10500 non-null   object
#  11  Cancelled Rides by Driver          27000 non-null   float64
#  12  Driver Cancellation Reason         27000 non-null   object
#  13  Incomplete Rides                   9000 non-null    float64
#  14  Incomplete Rides Reason            9000 non-null    object
#  15  Booking Value                      102000 non-null  float64
#  16  Ride Distance                      102000 non-null  float64
#  17  Driver Ratings                     93000 non-null   float64
#  18  Customer Rating                    93000 non-null   float64
#  19  Payment Method                     102000 non-null  object
# dtypes: float64(9), object(11)
# memory usage: 28.1+ MB

# %%
df.isna().sum()
# Out:
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
df.describe()
# Out:
#             Avg VTAT       Avg CTAT  Cancelled Rides by Customer  \
# count  139500.000000  102000.000000                      10500.0
# mean        8.456352      29.149636                          1.0
# std         3.773564       8.902577                          0.0
# min         2.000000      10.000000                          1.0
# 25%         5.300000      21.600000                          1.0
# 50%         8.300000      28.800000                          1.0
# 75%        11.300000      36.800000                          1.0
# max        20.000000      45.000000                          1.0
#
#        Cancelled Rides by Driver  Incomplete Rides  Booking Value  \
# count                    27000.0            9000.0  102000.000000
# mean                         1.0               1.0     508.295912
# std                          0.0               0.0     395.805774
# min                          1.0               1.0      50.000000
# 25%                          1.0               1.0     234.000000
# 50%                          1.0               1.0     414.000000
# 75%                          1.0               1.0     689.000000
# max                          1.0               1.0    4277.000000
#
#        Ride Distance  Driver Ratings  Customer Rating
# count  102000.000000    93000.000000     93000.000000
# mean       24.637012        4.230992         4.404584
# std        14.002138        0.436871         0.437819
# min         1.000000        3.000000         3.000000
# 25%        12.460000        4.100000         4.200000
# 50%        23.720000        4.300000         4.500000
# 75%        36.820000        4.600000         4.800000
# max        50.000000        5.000000         5.000000

# %% [markdown]
# #DATA PREPARATION

# %%
# 1. Mengubah kolom Time menjadi format datetime (SUDAH BENAR)
df['Time'] = pd.to_datetime(df['Time'])
# Out:
# /tmp/ipython-input-2020961617.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])

# %%
# 2. mengubah kolom Incomplete Ridesmenjadi Float
df['Incomplete Rides'] = df['Incomplete Rides'].astype(float)

# %% [markdown]
# #Drop Column we dont need

# %%
df = df.drop(columns=['Booking ID', 'Customer ID'])

# %% [markdown]
# # fill in the Na value

# %%
# FILL Na to 0 (use LIST for neat)
indicator_cols = [
    'Cancelled Rides by Customer',
    'Cancelled Rides by Driver',
    'Incomplete Rides'
]

df[indicator_cols] = df[indicator_cols].fillna(0)

# %% [markdown]
# #fill in 0 so that the value is 1 which means yes and 0 which means **no** use LIST

# %%
#fill Na to MEAN (use LOOP)
mean_cols = [
    'Avg VTAT',
    'Avg CTAT',
    'Ride Distance',
    'Driver Ratings',
    'Customer Rating'
]

for col in mean_cols:
    df[col] = df[col].fillna(df[col].mean())

# %% [markdown]
# #Fill in the Na value to MEAN use LOOP, so that the data has clear results and the data becomes accurate.

# %%
# fill Na to MEDIAN (outlier)
df['Booking Value'] = df['Booking Value'].fillna(df['Booking Value'].median())

# %% [markdown]
# # Fill in the Booking Value with Mean because there is an OUTLIER in the data

# %%
# fill Category Columns
df['Payment Method'] = df['Payment Method'].fillna(df['Payment Method'].mode()[0])

# %% [markdown]
# # fill the column using MODE because the column is an object/string

# %%
# re-check
df.isna().sum()
# Out:
# Time                                      0
# Booking Status                            0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                                  0
# Avg CTAT                                  0
# Cancelled Rides by Customer               0
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver                 0
# Driver Cancellation Reason           123000
# Incomplete Rides                          0
# Incomplete Rides Reason              141000
# Booking Value                             0
# Ride Distance                             0
# Driver Ratings                            0
# Customer Rating                           0
# Payment Method                            0
# dtype: int64

# %% [markdown]
# # So the data is neat and there are no more Na's, the ones that aren't there yet are because they are in string/object form.

# %%
df['Cancelled Rides by Customer'].mean() * 100
df['Cancelled Rides by Driver'].mean() * 100
df['Incomplete Rides'].mean() * 100
# Out:
# np.float64(6.0)

# %%
df.value_counts('Vehicle Type')
# Out:
# Vehicle Type
# Auto             37419
# Go Mini          29806
# Go Sedan         27141
# Bike             22517
# Premier Sedan    18111
# eBike            10557
# Uber XL           4449
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6)) # Memperbesar ukuran kanvas
sns.histplot(df['Vehicle Type'])
plt.title('Car Category Distribution')

# Putar label 45 derajat agar tidak tabrakan
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #Based on the graph, the most frequently ordered type in the application is auto.

# %%
df.head()
# Out:
#                           Time   Booking Status   Vehicle Type  \
# Date
# 2024-03-23 2026-02-16 12:29:38  No Driver Found          eBike
# 2024-11-29 2026-02-16 18:01:39       Incomplete       Go Sedan
# 2024-08-23 2026-02-16 08:56:10        Completed           Auto
# 2024-10-21 2026-02-16 17:17:25        Completed  Premier Sedan
# 2024-09-16 2026-02-16 22:08:00        Completed           Bike
#
#                 Pickup Location      Drop Location   Avg VTAT   Avg CTAT  \
# Date
# 2024-03-23          Palam Vihar            Jhilmil   8.456352  29.149636
# 2024-11-29        Shastri Nagar  Gurgaon Sector 56   4.900000  14.000000
# 2024-08-23              Khandsa      Malviya Nagar  13.400000  25.800000
# 2024-10-21  Central Secretariat           Inderlok  13.100000  28.500000
# 2024-09-16     Ghitorni Village        Khan Market   5.300000  19.600000
#
#             Cancelled Rides by Customer Reason for cancelling by Customer  \
# Date
# 2024-03-23                          0.0                               NaN
# 2024-11-29                          0.0                               NaN
# 2024-08-23                          0.0                               NaN
# 2024-10-21                          0.0                               NaN
# 2024-09-16                          0.0                               NaN
#
#             Cancelled Rides by Driver Driver Cancellation Reason  \
# Date
# 2024-03-23                        0.0                        NaN
# 2024-11-29                        0.0                        NaN
# 2024-08-23                        0.0                        NaN
# 2024-10-21                        0.0                        NaN
# 2024-09-16                        0.0                        NaN
#
#             Incomplete Rides Incomplete Rides Reason  Booking Value  \
# Date
# 2024-03-23               0.0                     NaN          414.0
# 2024-11-29               1.0       Vehicle Breakdown          237.0
# 2024-08-23               0.0                     NaN          627.0
# 2024-10-21               0.0                     NaN          416.0
# 2024-09-16               0.0                     NaN          737.0
#
#             Ride Distance  Driver Ratings  Customer Rating Payment Method
# Date
# 2024-03-23      24.637012        4.230992         4.404584            UPI
# 2024-11-29       5.730000        4.230992         4.404584            UPI
# 2024-08-23      13.580000        4.900000         4.900000     Debit Card
# 2024-10-21      34.020000        4.600000         5.000000            UPI
# 2024-09-16      48.210000        4.100000         4.300000            UPI

# %%
# Menghitung frekuensi tiap Pickup Location dan mengurutkannya
top_pickup = df['Pickup Location'].value_counts().head(10)
print("Top 10 Lokasi Jemput:")
print(top_pickup)

# Visualisasi sederhana
top_pickup.plot(kind='barh', color='skyblue')
plt.title('Top 10 Pickup Locations')
plt.gca().invert_yaxis() # Biar yang paling banyak ada di atas
plt.show()
# Out:
# Top 10 Lokasi Jemput:
# Pickup Location
# Khandsa             949
# Barakhamba Road     946
# Saket               931
# Badarpur            921
# Pragati Maidan      920
# Madipur             919
# AIIMS               918
# Mehrauli            915
# Dwarka Sector 21    914
# Pataudi Chowk       907
# Name: count, dtype: int64

# %%
# Menghitung frekuensi tiap Pickup Location dan mengurutkannya
top_drop = df['Drop Location'].value_counts().head(10)
print("Top 10 Lokasi Turun:")
print(top_drop)

# Visualisasi sederhana
top_drop.plot(kind='barh', color='skyblue')
plt.title('Top 10 Drop Locations')
plt.gca().invert_yaxis() # Biar yang paling banyak ada di atas
plt.show()
# Out:
# Top 10 Lokasi Turun:
# Drop Location
# Ashram                936
# Basai Dhankot         917
# Lok Kalyan Marg       916
# Narsinghpur           913
# Cyber Hub             912
# Kalkaji               912
# Kashmere Gate ISBT    909
# Udyog Vihar           906
# Lajpat Nagar          904
# Madipur               902
# Name: count, dtype: int64
